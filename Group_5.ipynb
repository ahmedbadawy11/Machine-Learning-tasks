# %% [markdown]
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image1.jpeg"
# style="width:1.71333in;height:1.71333in" />
#
# **ELG 5255: Applied Machine Learning**
#
# **<u>Assignment:2</u>**
#
# **BY: Group 5**
#
# Anas Elbattra
#
# Ahmed Badawy
#
# Esraa Fayad
#
# **<u>Part 1</u>**
#
# 1.  <img
#     src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image2.png"
#     style="width:3.2875in;height:4.57222in" /><img
#     src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image3.png"
#     style="width:3.54375in;height:4.5375in" />
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image4.png"
# style="width:3.43194in;height:5.18403in" /><img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image5.png"
# style="width:3.52778in;height:5.17708in" />
#
# 1.  <img
#     src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image6.png"
#     style="width:4.05458in;height:3.33547in" /><img
#     src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image7.png"
#     style="width:3.26111in;height:4.4in" />
#
# **<u>Part 2 Naive Bayes</u>**
#
# **<u>Function conf_matrix</u>**
#
# To preview the confusion matrix and classification report
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image8.png"
# style="width:5.97569in;height:3.27986in" />
#
# **<u>Read Date from URL</u>**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image9.png"
# style="width:6.36736in;height:0.736in" />
#
# **<u>Show The First 5 Rows</u>**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image10.png"
# style="width:6.49583in;height:2.06389in" />
#
# **<u>Show Value Counts for Spam</u>**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image11.png"
# style="width:4.27986in;height:1.05625in" />
#
# **<u>Part 2 (A)</u>**
#
# **Split the dataset into two parts as training data and test data**
#
# -   **first 80 percent for training**
#
# -   **last 20 percent for test**
#
# > <img
# > src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image12.png"
# > style="width:5.85625in;height:0.67986in" />
# >
# > **split first_80_percent for x_train and y_train and split
# > last_20_percen for x_test and y_test**
# >
# > <img
# > src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image13.png"
# > style="width:6.49583in;height:0.81597in" />
#
# **Function "Naive_Bayes_Models"**
#
# -   **this is user defined function whice apply Naive Bayes models**
#
# -   **It Takes 4 parameters Naive_Bayes_classifier , X\_\_train ,
#     Y\_\_train , X\_\_test**
#
# -   **then path X\_\_train and Y\_\_train to fit function then path
#     X\_\_test to predict functoin to calculate classifier_predictions**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image14.png"
# style="width:6.15972in;height:0.92014in" />
#
# **Run "Naive_Bayes_Models" Function using GaussianNB classifier**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image15.png"
# style="width:6.49583in;height:0.24792in" />
#
# **Display the confusion matrix for GaussianNB classifier**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image16.png"
# style="width:6.49583in;height:3.72778in" />
#
# **Run "Naive_Bayes_Models" Function using MultinomialNB classifier**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image17.png"
# style="width:6.49583in;height:0.28819in" />
#
# **Display the confusion matrix for MultinomialNB classifier**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image18.png"
# style="width:6.49583in;height:3.64792in" />
#
# **<u>Part 2 (B)</u>**
#
# **Put All columns except the last one in X Put the last column in Y and
# split X , Y using train_test_split function**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image19.png"
# style="width:6.49583in;height:0.67986in" />
#
# **Run "Naive_Bayes_Models" Function using GaussianNB classifier based on
# train test split function**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image20.png"
# style="width:6.568in;height:0.24026in" />
#
# **Display the confusion matrix for GaussianNB classifier**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image21.png"
# style="width:6.49583in;height:3.68819in" />
#
# **Run "Naive_Bayes_Models" Function using** **MultinomialNB classifier
# based on train test split function**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image22.png"
# style="width:6.48819in;height:0.18403in" />
#
# **Display the confusion matrix for MultinomialNB classifier**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image23.png"
# style="width:6.48819in;height:3.19167in" />
#
# **<u>Part 2 (C)</u>**
#
# **Run "Naive_Bayes_Models" Function using BernoulliNB classifier based
# on train test split function**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image24.png"
# style="width:6.49583in;height:0.21597in" />
#
# **Display the confusion matrix and Classification Report for BernoulliNB
# classifier**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image25.png"
# style="width:6.49583in;height:4.73611in" />
#
# **Display Accuracy Score for BernoulliNB classifier**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image26.png"
# style="width:6.48819in;height:0.48819in" />
#
# **I choose BernoulliNB classifier because the Target column (Spam) has
# two classes (1) or not (0)**
#
# **I noticed that spam column imbalanced and Class imbalance can have an
# impact on the performance of classifiers and BernoulliNB is a classifier
# that can handle imbalanced datasets effectively, particularly when the
# features are binary.** **This classifier has the ability to capture the
# patterns associated with the minority class (spam) while disregarding
# the patterns linked to the majority class (non-spam).But** **classifiers
# like MultinomialNB and GaussianNB might be susceptible to the influence
# of class imbalance.**
#
# **<u>Part 2 (D)</u>**
#
# **Split the first_80_percent into four equal parts (25%)**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image27.png"
# style="width:6.49583in;height:0.77569in" />
#
# **Put the four equal parts into List of 4 subset**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image28.png"
# style="width:5.90417in;height:0.33611in" />
#
# **loop on list_of_subset to access each sub_set**
#
# -   **Put All columns except the last one in x_train_sub_set**
#
# -   **Put the last column in y_train_sub_set**
#
# -   **then Run "Naive_Bayes_Models" Function using BernoulliNB
#     classifier for each sub_set**
#
# -   **predict the accuracy score by last 20 percent**
#
# -   **store the accuracy score for each sub_set in subset_accuracies
#     list**
#
# > <img
# > src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image29.png"
# > style="width:6.48819in;height:3.27986in" />
#
# **Plot the bar chart to visualize the accuracy scores of the subsets**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image30.png"
# style="width:6.48819in;height:4.02431in" />
#
# **We got accuracy zero for Subset 1, 64% for Subset 2, 100% for Subset
# 3, and 100% for Subset 4.**
#
# **We got accuracy zero for Subset 1 because all the training data in
# Subset 1 has class (1) only for the 'spam' column, whereas the test data
# for this Subset has class (0) only for the 'spam' column. Therefore, we
# obtained zero accuracy because the model was trained on one class and
# tested on another class for 'spam'
# **
#
# **We got an accuracy of 64% for Subset 2 because the training data in
# Subset 2 consisted of 893 rows for class (1) and 27 rows for class (0)
# for the 'spam' column. However, the test data for this Subset had only
# class (0) for the 'spam' column. As a result, we obtained 64% accuracy
# because the model was trained on insufficient data for class (0) and
# most of the training focused on class (1) for the 'spam' column, while
# the test was conducted on class (0) for 'spam'.**
#
# **We got an 100% accuracy for Subset 3 and Subset 4 because all the
# training data in both subsets exclusively consisted of class (0) for the
# 'spam' column. Similarly, the test data for these subsets only contained
# class (0) for the 'spam' column. As a result, we obtained 100% accuracy
# because the model was trained on an adequate amount of data for class
# (0) in the 'spam' column and tested on the same class (0) for 'spam'.**
#
# **<u>Show Value Counts and shape for Spam column for each Sub_Set
# \[taining data ,test data\]</u>**
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image31.png"
# style="width:6.48819in;height:2.32014in" />
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image32.png"
# style="width:6.45625in;height:7.07222in" />
#
# <img
# src="attachment:vertopal_3c4dc2f050984af18fb47ad257d6d969/media/image33.png"
# style="width:6.49583in;height:6.74375in" />
